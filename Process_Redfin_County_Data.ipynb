# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
df_original = pd.read_csv('data/redfin_county_data.csv', sep='\t')

# %%
df_copy = df_original.copy()

# %%
df_copy
# Out:
#        period_begin  period_end  period_duration region_type  region_type_id
# 0        2023-02-01  2023-02-28               30      county               5  \
# 1        2022-04-01  2022-04-30               30      county               5
# 2        2022-04-01  2022-04-30               30      county               5
# 3        2022-07-01  2022-07-31               30      county               5
# 4        2022-02-01  2022-02-28               30      county               5
# ...             ...         ...              ...         ...             ...
# 117964   2022-02-01  2022-02-28               30      county               5
# 117965   2022-12-01  2022-12-31               30      county               5
# 117966   2022-09-01  2022-09-30               30      county               5
# 117967   2022-12-01  2022-12-31               30      county               5
# 117968   2022-09-01  2022-09-30               30      county               5
#
#         table_id is_seasonally_adjusted               region  city
# 0           2429                      f      Kent County, RI   NaN  \
# 1            519                      f   Bulloch County, GA   NaN
# 2           1193                      f    Mercer County, KY   NaN
# 3           3078                      f   Cowlitz County, WA   NaN
# 4            987                      f     Scott County, IA   NaN
# ...          ...                    ...                  ...   ...
# 117964      2379                      f  Columbia County, PA   NaN
# 117965      3043                      f     Falls Church, VA   NaN
# 117966      1907                      f     Salem County, NJ   NaN
# 117967      1185                      f   Madison County, KY   NaN
# 117968      2899                      f     Davis County, UT   NaN
#
#                state state_code              property_type  property_type_id
# 0       Rhode Island         RI    Multi-Family (2-4 Unit)                 4  \
# 1            Georgia         GA            All Residential                -1
# 2           Kentucky         KY                  Townhouse                13
# 3         Washington         WA  Single Family Residential                 6
# 4               Iowa         IA                Condo/Co-op                 3
# ...              ...        ...                        ...               ...
# 117964  Pennsylvania         PA                  Townhouse                13
# 117965      Virginia         VA            All Residential                -1
# 117966    New Jersey         NJ    Multi-Family (2-4 Unit)                 4
# 117967      Kentucky         KY    Multi-Family (2-4 Unit)                 4
# 117968          Utah         UT    Multi-Family (2-4 Unit)                 4
#
#         median_sale_price  median_sale_price_mom  median_sale_price_yoy
# 0                377000.0               0.256667              -0.020779  \
# 1                210000.0              -0.094828              -0.009200
# 2                342500.0                    NaN                    NaN
# 3                381213.0              -0.023782               0.003324
# 4                 95000.0              -0.707405                    NaN
# ...                   ...                    ...                    ...
# 117964           179000.0               0.205387              -0.251046
# 117965           800000.0               0.111876               0.041667
# 117966           225000.0               0.000000               0.666667
# 117967           266750.0               0.056436              -0.170112
# 117968           552000.0              -0.283117              -0.157252
#
#         median_list_price  median_list_price_mom  median_list_price_yoy
# 0                359000.0               0.028653               0.071642  \
# 1                239995.0              -0.076765               0.170707
# 2                     NaN                    NaN                    NaN
# 3                425000.0               0.070664               0.183844
# 4                     NaN                    NaN                    NaN
# ...                   ...                    ...                    ...
# 117964           184450.0                    NaN               0.054000
# 117965           762500.0              -0.175230              -0.244676
# 117966           237500.0               0.055556               0.199798
# 117967           253500.0              -0.043396               0.056470
# 117968           514900.0              -0.009712               0.072708
#
#         median_ppsf  median_ppsf_mom  median_ppsf_yoy  median_list_ppsf
# 0        151.261284         0.080324         0.165409        223.333333  \
# 1        135.015130         0.000056         0.240334        141.615620
# 2        239.471511              NaN              NaN               NaN
# 3        262.552521         0.012709         0.064021        242.022494
# 4        164.075993        -0.269270              NaN               NaN
# ...             ...              ...              ...               ...
# 117964   116.688396         0.038373        -0.219799        124.461207
# 117965   394.105552         0.240749        -0.071060        457.170533
# 117966    81.437126        -0.319837         0.122023        139.942857
# 117967    89.394144        -0.076517        -0.278014        144.444444
# 117968   257.464789         0.346173         0.265749        216.417910
#
#         median_list_ppsf_mom  median_list_ppsf_yoy  homes_sold
# 0                   0.004012              0.030671         4.0  \
# 1                  -0.015304              0.254727        99.0
# 2                        NaN                   NaN         2.0
# 3                  -0.065260              0.073391       147.0
# 4                        NaN                   NaN         1.0
# ...                      ...                   ...         ...
# 117964                   NaN              0.227811         1.0
# 117965              0.066203              0.236017         5.0
# 117966             -0.069918              0.008904         3.0
# 117967              0.028378              0.039874         4.0
# 117968             -0.030007              0.053633         3.0
#
#         homes_sold_mom  homes_sold_yoy  pending_sales  pending_sales_mom
# 0            -0.428571       -0.666667            8.0           1.000000  \
# 1            -0.116071        0.164706          102.0          -0.055556
# 2                  NaN             NaN            NaN                NaN
# 3             0.204918       -0.032895          139.0          -0.079470
# 4            -0.500000             NaN            NaN                NaN
# ...                ...             ...            ...                ...
# 117964       -0.500000        0.000000            1.0           0.000000
# 117965       -0.375000       -0.642857            5.0           0.000000
# 117966       -0.571429        0.000000            7.0           2.500000
# 117967        0.000000       -0.600000            1.0          -0.875000
# 117968        0.000000       -0.571429            1.0          -0.800000
#
#         pending_sales_yoy  new_listings  new_listings_mom  new_listings_yoy
# 0               -0.384615           8.0         -0.333333         -0.384615  \
# 1               -0.089286          87.0         -0.360294         -0.382979
# 2                     NaN           NaN               NaN               NaN
# 3               -0.114650         175.0         -0.150485         -0.011299
# 4                     NaN           NaN               NaN               NaN
# ...                   ...           ...               ...               ...
# 117964                NaN           1.0               NaN          0.000000
# 117965          -0.500000           6.0          0.500000          0.000000
# 117966          -0.125000           5.0          0.666667         -0.166667
# 117967          -0.916667           3.0         -0.571429         -0.700000
# 117968          -0.800000           1.0         -0.800000         -0.800000
#
#         inventory  inventory_mom  inventory_yoy  months_of_supply
# 0            20.0      -0.130435       0.052632               5.0  \
# 1           149.0      -0.123529       0.146154               1.5
# 2             1.0            NaN            NaN               0.5
# 3           265.0       0.099585       0.802721               1.8
# 4             4.0       0.000000            NaN               4.0
# ...           ...            ...            ...               ...
# 117964        1.0       0.000000      -0.500000               1.0
# 117965       10.0       0.000000      -0.090909               2.0
# 117966        9.0      -0.307692      -0.666667               3.0
# 117967        3.0       0.500000       2.000000               0.8
# 117968        6.0       0.000000       0.200000               2.0
#
#         months_of_supply_mom  months_of_supply_yoy  median_dom
# 0                        1.7                   3.4        97.0  \
# 1                        0.0                   0.0        19.0
# 2                        NaN                   NaN         4.0
# 3                       -0.2                   0.8        10.0
# 4                        2.0                   NaN      7725.0
# ...                      ...                   ...         ...
# 117964                   0.5                  -1.0        51.0
# 117965                   0.7                   1.2        33.0
# 117966                   1.1                  -6.0        52.0
# 117967                   0.3                   0.7        12.0
# 117968                   0.0                   1.3        29.0
#
#         median_dom_mom  median_dom_yoy  avg_sale_to_list
# 0                 86.0            63.0          0.973341  \
# 1                 -9.0             1.0          1.006817
# 2                  NaN             NaN          0.984950
# 3                 -2.0             2.0          1.009263
# 4               7591.0             NaN          1.585977
# ...                ...             ...               ...
# 117964           -35.0          -123.0          1.000000
# 117965           -25.0           -19.0          0.984598
# 117966           -10.0            20.0          0.977339
# 117967           -58.0          -171.0          0.983906
# 117968           -10.0             2.0          0.970678
#
#         avg_sale_to_list_mom  avg_sale_to_list_yoy  sold_above_list
# 0                  -0.011071             -0.022020         0.500000  \
# 1                   0.020355              0.022923         0.333333
# 2                        NaN                   NaN         0.000000
# 3                   0.004183             -0.017736         0.544218
# 4                   0.580811                   NaN         1.000000
# ...                      ...                   ...              ...
# 117964             -0.022201              0.003752         0.000000
# 117965              0.027759             -0.001517         0.200000
# 117966              0.111822              0.025325         0.000000
# 117967             -0.004270             -0.007812         0.500000
# 117968             -0.012586              0.016162         0.333333
#
#         sold_above_list_mom  sold_above_list_yoy  price_drops
# 0                  0.071429             0.166667     0.250000  \
# 1                  0.002976             0.062745     0.053691
# 2                       NaN                  NaN     1.000000
# 3                  0.027824            -0.028151     0.501887
# 4                  0.500000                  NaN          NaN
# ...                     ...                  ...          ...
# 117964            -0.500000             0.000000          NaN
# 117965             0.075000            -0.085714     0.300000
# 117966             0.000000             0.000000     0.111111
# 117967             0.500000             0.500000     0.666667
# 117968             0.333333             0.333333     0.500000
#
#         price_drops_mom  price_drops_yoy  off_market_in_two_weeks
# 0              0.163043         0.197368                 0.500000  \
# 1              0.000750        -0.000155                 0.441176
# 2                   NaN              NaN                      NaN
# 3              0.028858         0.073315                 0.467626
# 4                   NaN              NaN                      NaN
# ...                 ...              ...                      ...
# 117964              NaN              NaN                 0.000000
# 117965         0.100000         0.118182                 0.000000
# 117966        -0.119658        -0.148148                 0.285714
# 117967              NaN              NaN                 0.000000
# 117968         0.333333         0.300000                 0.000000
#
#         off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy
# 0                          0.500000                    -0.115385  \
# 1                         -0.086601                    -0.237395
# 2                               NaN                          NaN
# 3                         -0.154891                    -0.245750
# 4                               NaN                          NaN
# ...                             ...                          ...
# 117964                     0.000000                          NaN
# 117965                     0.000000                    -0.300000
# 117966                     0.285714                    -0.089286
# 117967                    -0.750000                    -0.916667
# 117968                    -0.200000                    -0.600000
#
#                   parent_metro_region  parent_metro_region_metro_code
# 0                      Providence, RI                         39300.0  \
# 1                      Statesboro, GA                         44340.0
# 2       Kentucky nonmetropolitan area                             NaN
# 3                        Longview, WA                         31020.0
# 4                       Davenport, IA                         19340.0
# ...                               ...                             ...
# 117964                 Bloomsburg, PA                         14100.0
# 117965                 Washington, DC                         47894.0
# 117966                 Wilmington, DE                         48864.0
# 117967                   Richmond, KY                         40080.0
# 117968                      Ogden, UT                         36260.0
#
#                last_updated
# 0       2023-04-09 14:55:08
# 1       2023-04-09 14:55:08
# 2       2023-04-09 14:55:08
# 3       2023-04-09 14:55:08
# 4       2023-04-09 14:55:08
# ...                     ...
# 117964  2023-04-09 14:55:08
# 117965  2023-04-09 14:55:08
# 117966  2023-04-09 14:55:08
# 117967  2023-04-09 14:55:08
# 117968  2023-04-09 14:55:08
#
# [117969 rows x 58 columns]

# %%
df = df_copy.loc[:, ['period_begin', 'region', 'state', 'state_code', 'property_type', 'homes_sold', 'new_listings', 'inventory', 'median_dom', 'months_of_supply', 'avg_sale_to_list', 'last_updated']]

# %%
df = df.sort_values(by='period_begin', ascending=False)
df = df.reset_index(drop=True)
df = df.rename(columns={'region':'county', 'period_begin': 'month'})
df
# Out:
#              month                 county       state state_code
# 0       2023-03-01    Plymouth County, IA        Iowa         IA  \
# 1       2023-03-01    Sullivan County, NY    New York         NY
# 2       2023-03-01  Washington County, CO    Colorado         CO
# 3       2023-03-01     Decatur County, TN   Tennessee         TN
# 4       2023-03-01    Somerset County, NJ  New Jersey         NJ
# ...            ...                    ...         ...        ...
# 117964  2022-01-01     Madison County, MO    Missouri         MO
# 117965  2022-01-01   Christian County, KY    Kentucky         KY
# 117966  2022-01-01         Ada County, ID       Idaho         ID
# 117967  2022-01-01  Montgomery County, TN   Tennessee         TN
# 117968  2022-01-01     Larimer County, CO    Colorado         CO
#
#                     property_type  homes_sold  new_listings  inventory
# 0                 All Residential         3.0          13.0       17.0  \
# 1         Multi-Family (2-4 Unit)         4.0           4.0       11.0
# 2       Single Family Residential         7.0           2.0       11.0
# 3       Single Family Residential         8.0          14.0       41.0
# 4       Single Family Residential       230.0         240.0      296.0
# ...                           ...         ...           ...        ...
# 117964            All Residential        13.0          14.0       24.0
# 117965  Single Family Residential        37.0          28.0       47.0
# 117966            All Residential       711.0         739.0      760.0
# 117967                Condo/Co-op        13.0          19.0       43.0
# 117968  Single Family Residential       279.0         295.0      412.0
#
#         median_dom  months_of_supply  avg_sale_to_list         last_updated
# 0             12.0               5.7          1.017140  2023-04-09 14:55:08
# 1            103.0               2.8          0.936421  2023-04-09 14:55:08
# 2            157.0               1.6          0.953884  2023-04-09 14:55:08
# 3             66.0               5.1          0.897618  2023-04-09 14:55:08
# 4             22.0               1.3          1.016352  2023-04-09 14:55:08
# ...            ...               ...               ...                  ...
# 117964        77.0               1.8          0.944636  2023-04-09 14:55:08
# 117965        53.0               1.3          0.991711  2023-04-09 14:55:08
# 117966        28.0               1.1          0.995313  2023-04-09 14:55:08
# 117967        58.0               3.3          0.992386  2023-04-09 14:55:08
# 117968        37.0               1.5          1.013137  2023-04-09 14:55:08
#
# [117969 rows x 12 columns]

# %%
# Convert the 'month' column to a datetime object
df['month'] = pd.to_datetime(df['month'])
df['county_name'] = df['county'].apply(lambda x: x.split(',')[0] if ',' in x else x)

filtered_df = df[df['month'] >= '2022-01-01']
df_residential = filtered_df[filtered_df['property_type'] == 'All Residential']

df_residential
# Out:
#             month                 county           state state_code
# 0      2023-03-01    Plymouth County, IA            Iowa         IA  \
# 6      2023-03-01  Cumberland County, IL        Illinois         IL
# 10     2023-03-01       Moore County, NC  North Carolina         NC
# 11     2023-03-01    Plymouth County, MA   Massachusetts         MA
# 12     2023-03-01        Cole County, MO        Missouri         MO
# ...           ...                    ...             ...        ...
# 117957 2022-01-01     Hancock County, ME           Maine         ME
# 117961 2022-01-01    Sullivan County, NH   New Hampshire         NH
# 117963 2022-01-01       Pecos County, TX           Texas         TX
# 117964 2022-01-01     Madison County, MO        Missouri         MO
# 117966 2022-01-01         Ada County, ID           Idaho         ID
#
#           property_type  homes_sold  new_listings  inventory  median_dom
# 0       All Residential         3.0          13.0       17.0        12.0  \
# 6       All Residential         4.0           5.0       13.0        15.0
# 10      All Residential       209.0         217.0      244.0        29.0
# 11      All Residential       327.0         552.0      638.0        29.0
# 12      All Residential        60.0          67.0       67.0         8.0
# ...                 ...         ...           ...        ...         ...
# 117957  All Residential        67.0          25.0      106.0        40.0
# 117961  All Residential        34.0          23.0       83.0        63.0
# 117963  All Residential         2.0           9.0       43.0        61.0
# 117964  All Residential        13.0          14.0       24.0        77.0
# 117966  All Residential       711.0         739.0      760.0        28.0
#
#         months_of_supply  avg_sale_to_list         last_updated
# 0                    5.7          1.017140  2023-04-09 14:55:08  \
# 6                    3.3          1.028047  2023-04-09 14:55:08
# 10                   1.2          0.992340  2023-04-09 14:55:08
# 11                   2.0          0.998781  2023-04-09 14:55:08
# 12                   1.1          1.000707  2023-04-09 14:55:08
# ...                  ...               ...                  ...
# 117957               1.6          0.964497  2023-04-09 14:55:08
# 117961               2.4          1.005345  2023-04-09 14:55:08
# 117963              21.5               NaN  2023-04-09 14:55:08
# 117964               1.8          0.944636  2023-04-09 14:55:08
# 117966               1.1          0.995313  2023-04-09 14:55:08
#
#               county_name
# 0         Plymouth County
# 6       Cumberland County
# 10           Moore County
# 11        Plymouth County
# 12            Cole County
# ...                   ...
# 117957     Hancock County
# 117961    Sullivan County
# 117963       Pecos County
# 117964     Madison County
# 117966         Ada County
#
# [39437 rows x 13 columns]

# %%
df = df_residential.copy()

# %%
# Drop the 'county' and 'state' columns
df = df.drop(columns=['county', 'state'])

# Rearrange the columns
df = df[['month', 'county_name', 'state_code', 'property_type', 'homes_sold', 'new_listings', 'inventory', 
         'median_dom', 'months_of_supply', 'avg_sale_to_list', 'last_updated']]

df = df.sort_values(by=['state_code', 'county_name', 'month'])

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Drop the 'county' and 'state' columns
# ----> 2 df = df.drop(columns=['county', 'state'])
#       4 # Rearrange the columns
#       5 df = df[['month', 'county_name', 'state_code', 'property_type', 'homes_sold', 'new_listings', 'inventory',
#       6          'median_dom', 'months_of_supply', 'avg_sale_to_list', 'last_updated']]
#
# File ~/side/county_research/county/lib/python3.9/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File ~/side/county_research/county/lib/python3.9/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/side/county_research/county/lib/python3.9/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/side/county_research/county/lib/python3.9/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['county', 'state'] not found in axis"

# %%
# Get today's date
today = datetime.date.today()
date_string = today.strftime("%Y-%m-%d")
file_path = f"data/redfin_processed_output_{date_string}.csv"
df.to_csv(file_path, index=False)
