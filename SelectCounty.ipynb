# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
redfin_df = pd.read_csv('processed/redfin_month_rollup_2023-06.tsv', sep='\t')
redfin_df
# Out:
#        county_qualified_name  homes_sold  new_listings  inventory  median_dom
# 0      Anchorage Borough, AK      225.00        328.00     243.50       10.50  \
# 1      Anchorage Borough, AK      190.00        269.25     234.00       21.00
# 2      Anchorage Borough, AK      235.57        232.57     274.43       19.57
# 3      Anchorage Borough, AK      328.62        348.23     380.08       15.08
# 4      Anchorage Borough, AK      323.56        355.25     363.88       15.94
# ...                      ...         ...           ...        ...         ...
# 14292      Morgan County, WV       24.50         21.50      70.50       53.00
# 14293      Morgan County, WV       22.50         23.50      71.00       76.00
# 14294      Morgan County, WV       23.71         24.29      78.00       63.71
# 14295      Morgan County, WV       28.85         34.15      83.54       51.77
# 14296      Morgan County, WV       28.44         32.94      77.25       52.44
#
# ...

# %%
prcyd_df = pd.read_csv('processed/prycd_county_data_2023-06.tsv', sep='\t')
prcyd_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3519  Sweetwater County  Wyoming          196                   143
# 3520       Teton County  Wyoming         1223                  1220
# 3521       Uinta County  Wyoming          192                   191
# 3522    Washakie County  Wyoming           94                    90
# 3523      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# ...

# %%
merged_df = redfin_df.merge(prcyd_df, how='left', on='county_qualified_name')
merged_df
# Out:
#        county_qualified_name  homes_sold  new_listings  inventory  median_dom
# 0      Anchorage Borough, AK      225.00        328.00     243.50       10.50  \
# 1      Anchorage Borough, AK      190.00        269.25     234.00       21.00
# 2      Anchorage Borough, AK      235.57        232.57     274.43       19.57
# 3      Anchorage Borough, AK      328.62        348.23     380.08       15.08
# 4      Anchorage Borough, AK      323.56        355.25     363.88       15.94
# ...                      ...         ...           ...        ...         ...
# 16286      Morgan County, WV       24.50         21.50      70.50       53.00
# 16287      Morgan County, WV       22.50         23.50      71.00       76.00
# 16288      Morgan County, WV       23.71         24.29      78.00       63.71
# 16289      Morgan County, WV       28.85         34.15      83.54       51.77
# 16290      Morgan County, WV       28.44         32.94      77.25       52.44
#
# ...

# %%
filtered_df = merged_df.dropna(subset=['property_count'])
filtered_df
# Out:
#       county_qualified_name  homes_sold  new_listings  inventory  median_dom
# 45       Autauga County, AL       51.00         65.00     127.00       49.00  \
# 46       Autauga County, AL       44.50         63.50     123.25       47.00
# 47       Autauga County, AL       53.86         57.43     129.43       49.86
# 48       Autauga County, AL       70.85         72.77     160.69       48.92
# 49       Autauga County, AL       72.12         77.19     166.81       48.31
# ...                     ...         ...           ...        ...         ...
# 16286     Morgan County, WV       24.50         21.50      70.50       53.00
# 16287     Morgan County, WV       22.50         23.50      71.00       76.00
# 16288     Morgan County, WV       23.71         24.29      78.00       63.71
# 16289     Morgan County, WV       28.85         34.15      83.54       51.77
# 16290     Morgan County, WV       28.44         32.94      77.25       52.44
#
# ...
