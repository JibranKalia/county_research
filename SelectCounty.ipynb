# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
redfin_df_orig = pd.read_csv('processed/redfin_month_rollup_2023-06.tsv', sep='\t')
redfin_df
# Out:
#                   county_qualified_name  homes_sold  new_listings  inventory
# 1                 Anchorage Borough, AK      190.00        269.25     234.00  \
# 6                Bethel Census Area, AK        1.00          1.00       7.00
# 11                   Denali Borough, AK        1.00          1.00       3.00
# 16     Fairbanks North Star Borough, AK       67.75         95.25     209.25
# 21          Kenai Peninsula Borough, AK       35.50         68.00     148.00
# ...                                 ...         ...           ...        ...
# 14273              Hampshire County, WV       17.50         25.25      60.75
# 14278                  Hardy County, WV        9.75         13.50      32.00
# 14283              Jefferson County, WV       74.50         81.00     184.75
# 14288                Mineral County, WV       16.00         16.25      47.75
# 14293                 Morgan County, WV       22.50         23.50      71.00
#
# ...

# %%
redfin_df = redfin_df_orig[redfin_df_orig['months_averaged'].isin([3])]
redfin_df
# Out:
#                   county_qualified_name  homes_sold  new_listings  inventory
# 1                 Anchorage Borough, AK      190.00        269.25     234.00  \
# 6                Bethel Census Area, AK        1.00          1.00       7.00
# 11                   Denali Borough, AK        1.00          1.00       3.00
# 16     Fairbanks North Star Borough, AK       67.75         95.25     209.25
# 21          Kenai Peninsula Borough, AK       35.50         68.00     148.00
# ...                                 ...         ...           ...        ...
# 14273              Hampshire County, WV       17.50         25.25      60.75
# 14278                  Hardy County, WV        9.75         13.50      32.00
# 14283              Jefferson County, WV       74.50         81.00     184.75
# 14288                Mineral County, WV       16.00         16.25      47.75
# 14293                 Morgan County, WV       22.50         23.50      71.00
#
# ...

# %%
prcyd_df = pd.read_csv('processed/prycd_county_data_2023-06.tsv', sep='\t')
prcyd_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3519  Sweetwater County  Wyoming          196                   143
# 3520       Teton County  Wyoming         1223                  1220
# 3521       Uinta County  Wyoming          192                   191
# 3522    Washakie County  Wyoming           94                    90
# 3523      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# ...

# %%
merged_df = redfin_df.merge(prcyd_df, how='inner', on='county_qualified_name')
merged_df
# Out:
#                  county_qualified_name  homes_sold  new_listings  inventory
# 0                   Denali Borough, AK        1.00          1.00       3.00  \
# 1     Fairbanks North Star Borough, AK       67.75         95.25     209.25
# 2          Kenai Peninsula Borough, AK       35.50         68.00     148.00
# 3            Kodiak Island Borough, AK        2.00          4.00       5.50
# 4        Matanuska-Susitna Borough, AK      113.25        166.50     271.75
# ...                                ...         ...           ...        ...
# 3173              Hampshire County, WV       17.50         25.25      60.75
# 3174                  Hardy County, WV        9.75         13.50      32.00
# 3175              Jefferson County, WV       74.50         81.00     184.75
# 3176                Mineral County, WV       16.00         16.25      47.75
# 3177                 Morgan County, WV       22.50         23.50      71.00
#
# ...

# %%
combined_df = merged_df.dropna(subset=['inventory', 'homes_sold'])
combined_df
# Out:
#                  county_qualified_name  homes_sold  new_listings  inventory
# 0                   Denali Borough, AK        1.00          1.00       3.00  \
# 1     Fairbanks North Star Borough, AK       67.75         95.25     209.25
# 2          Kenai Peninsula Borough, AK       35.50         68.00     148.00
# 3            Kodiak Island Borough, AK        2.00          4.00       5.50
# 4        Matanuska-Susitna Borough, AK      113.25        166.50     271.75
# ...                                ...         ...           ...        ...
# 3173              Hampshire County, WV       17.50         25.25      60.75
# 3174                  Hardy County, WV        9.75         13.50      32.00
# 3175              Jefferson County, WV       74.50         81.00     184.75
# 3176                Mineral County, WV       16.00         16.25      47.75
# 3177                 Morgan County, WV       22.50         23.50      71.00
#
# ...

# %%
today = datetime.date.today()
date_string = today.strftime("%Y-%m")
file_path = f"processed/combined_county_data_{date_string}.tsv"

# %%
combined_df.to_csv(file_path, index=False, sep ='\t')
