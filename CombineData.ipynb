# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
redfin_df_orig = pd.read_excel('processed/redfin_month_rollup_2023-07-05.xlsx')
redfin_df_orig
# Out:
#                  county_qualified_name  homes_sold_redfin
# 0                Anchorage Borough, AK              211.8  \
# 1               Bethel Census Area, AK                1.5
# 2                   Denali Borough, AK                1.0
# 3     Fairbanks North Star Borough, AK               76.0
# 4          Kenai Peninsula Borough, AK               43.4
# ...                                ...                ...
# 2852              Hampshire County, WV               19.0
# 2853                  Hardy County, WV                9.6
# 2854              Jefferson County, WV               75.4
# 2855                Mineral County, WV               16.6
# 2856                 Morgan County, WV               23.8
#
#       new_listings_redfin  inventory_redfin  median_dom_redfin
# 0                   294.6             241.0               18.4  \
# 1                     1.0               8.5               77.0
# 2                     1.0               3.0               67.5
# 3                   107.6             209.4               67.0
# 4                    77.6             157.0               29.4
# ...                   ...               ...                ...
# 2852                 26.0              62.6               38.8
# 2853                 12.4              32.2               63.4
# 2854                 88.6             192.8               55.2
# 2855                 19.8              49.4               58.6
# 2856                 25.0              72.2               70.8
#
#       months_of_supply_redfin state_code                   county_name
# 0                        1.18         AK             Anchorage Borough  \
# 1                        6.75         AK            Bethel Census Area
# 2                        3.00         AK                Denali Borough
# 3                        3.10         AK  Fairbanks North Star Borough
# 4                        4.06         AK       Kenai Peninsula Borough
# ...                       ...        ...                           ...
# 2852                     3.48         WV              Hampshire County
# 2853                     3.38         WV                  Hardy County
# 2854                     2.64         WV              Jefferson County
# 2855                     3.12         WV                Mineral County
# 2856                     3.10         WV                 Morgan County
#
#       months_averaged_redfin
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
# ...                      ...
# 2852                       3
# 2853                       3
# 2854                       3
# 2855                       3
# 2856                       3
#
# [2857 rows x 9 columns]

# %%
# redfin_df = redfin_df_orig[redfin_df_orig['months_averaged_redfin'].isin([1, 3, 6, 12, 18])]
redfin_df = redfin_df_orig[redfin_df_orig['months_averaged_redfin'].isin([3])]
redfin_df
# Out:
#                  county_qualified_name  homes_sold_redfin
# 0                Anchorage Borough, AK              211.8  \
# 1               Bethel Census Area, AK                1.5
# 2                   Denali Borough, AK                1.0
# 3     Fairbanks North Star Borough, AK               76.0
# 4          Kenai Peninsula Borough, AK               43.4
# ...                                ...                ...
# 2852              Hampshire County, WV               19.0
# 2853                  Hardy County, WV                9.6
# 2854              Jefferson County, WV               75.4
# 2855                Mineral County, WV               16.6
# 2856                 Morgan County, WV               23.8
#
#       new_listings_redfin  inventory_redfin  median_dom_redfin
# 0                   294.6             241.0               18.4  \
# 1                     1.0               8.5               77.0
# 2                     1.0               3.0               67.5
# 3                   107.6             209.4               67.0
# 4                    77.6             157.0               29.4
# ...                   ...               ...                ...
# 2852                 26.0              62.6               38.8
# 2853                 12.4              32.2               63.4
# 2854                 88.6             192.8               55.2
# 2855                 19.8              49.4               58.6
# 2856                 25.0              72.2               70.8
#
#       months_of_supply_redfin state_code                   county_name
# 0                        1.18         AK             Anchorage Borough  \
# 1                        6.75         AK            Bethel Census Area
# 2                        3.00         AK                Denali Borough
# 3                        3.10         AK  Fairbanks North Star Borough
# 4                        4.06         AK       Kenai Peninsula Borough
# ...                       ...        ...                           ...
# 2852                     3.48         WV              Hampshire County
# 2853                     3.38         WV                  Hardy County
# 2854                     2.64         WV              Jefferson County
# 2855                     3.12         WV                Mineral County
# 2856                     3.10         WV                 Morgan County
#
#       months_averaged_redfin
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
# ...                      ...
# 2852                       3
# 2853                       3
# 2854                       3
# 2855                       3
# 2856                       3
#
# [2857 rows x 9 columns]

# %%
prcyd_df = pd.read_excel('processed/prycd_county_data_2023-07.xlsx')
prcyd_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3519  Sweetwater County  Wyoming          196                   143
# 3520       Teton County  Wyoming         1223                  1220
# 3521       Uinta County  Wyoming          192                   191
# 3522    Washakie County  Wyoming           94                    90
# 3523      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# 0                  238               70               36                 212  \
# 1                 2695              930              378                2678
# 2                   65                8                5                 224
# 3                   90               19                7                  69
# 4                  319               79               42                 291
# ...                ...              ...              ...                 ...
# 3519                53                0                0                  33
# 3520                 3                0                0                  56
# 3521                 1                0                0                  49
# 3522                 4                0                0                  37
# 3523                16                0                0                 118
#
#       Listed Comps (6m)  Listed Comps (3m)  Sold-For Sale Ratio
# 0                   185                 50                 0.37  \
# 1                  1907               1205                 0.50
# 2                   154                 72                 0.11
# 3                    47                 19                 0.51
# 4                   199                139                 0.39
# ...                 ...                ...                  ...
# 3519                 27                 11                 0.37
# 3520                 49                 47                 0.00
# 3521                 34                 14                 0.01
# 3522                 33                 33                 0.04
# 3523                 42                 12                 0.06
#
#       Sold-Listed Ratio (12m)  Sold-Listed Ratio (6m)  Sold-Listed Ratio (3m)
# 0                        1.12                    0.38                    0.72  \
# 1                        1.01                    0.49                    0.31
# 2                        0.29                    0.05                    0.07
# 3                        1.30                    0.40                    0.37
# 4                        1.10                    0.40                    0.30
# ...                       ...                     ...                     ...
# 3519                     1.61                    0.00                    0.00
# 3520                     0.05                    0.00                    0.00
# 3521                     0.02                    0.00                    0.00
# 3522                     0.11                    0.00                    0.00
# 3523                     0.14                    0.00                    0.00
#
#       Parcels on Market Ratio  Total DataTree Parcels
# 0                       0.080                    8002  \
# 1                       0.139                   38984
# 2                       0.048                   12726
# 3                       0.022                    8058
# 4                       0.039                   20841
# ...                       ...                     ...
# 3519                    0.045                    3200
# 3520                    0.555                    2199
# 3521                    0.076                    2521
# 3522                    0.090                     998
# 3523                    0.149                    1769
#
#       Total Out of State Owner Parcels  Total Out of County Owner Parcels
# 0                                  991                               3121  \
# 1                                 6143                              12890
# 2                                 2459                               5429
# 3                                  873                               3363
# 4                                 1148                               6146
# ...                                ...                                ...
# 3519                              1798                               2010
# 3520                               966                               1017
# 3521                               829                                955
# 3522                               120                                254
# 3523                               493                                720
#
#       Out of State to Total Ratio  Out of County to Total Ratio
# 0                           0.124                         0.390  \
# 1                           0.158                         0.331
# 2                           0.193                         0.427
# 3                           0.108                         0.417
# 4                           0.055                         0.295
# ...                           ...                           ...
# 3519                        0.562                         0.628
# 3520                        0.439                         0.462
# 3521                        0.329                         0.379
# 3522                        0.120                         0.255
# 3523                        0.279                         0.407
#
#       Coefficient of Variation  Coefficient of Variation (6m)
# 0                         0.88                           0.68  \
# 1                         1.19                           1.17
# 2                         0.60                           0.59
# 3                         0.40                           0.36
# 4                         0.77                           0.70
# ...                        ...                            ...
# 3519                      0.19                           0.20
# 3520                      0.38                           0.37
# 3521                      0.29                           0.29
# 3522                      0.16                           0.13
# 3523                      0.31                           0.31
#
#       Coefficient of Variation (3m)  Days on Market  MoM Price Change %
# 0                              0.67           479.8               -0.38  \
# 1                              1.16           174.8                3.15
# 2                              0.59           239.9                3.68
# 3                              0.36           204.4               -0.18
# 4                              0.67           258.0                0.42
# ...                             ...             ...                 ...
# 3519                           0.20           259.5                5.13
# 3520                           0.37            91.2               -2.23
# 3521                           0.29           162.0                1.44
# 3522                           0.13           223.8                0.16
# 3523                           0.31           274.5                1.55
#
#       Economic Rank  Economic Score  Population
# 0             726.0            0.70       55869  \
# 1             398.0            1.42      223234
# 2            1647.0           -0.19       24686
# 3            1722.0           -0.24       22394
# 4            1149.0            0.23       57826
# ...             ...             ...         ...
# 3519          224.0            2.20       42343
# 3520           54.0            3.91       23464
# 3521          189.0            2.46       20226
# 3522          496.0            1.16        7805
# 3523         1620.0           -0.17        6927
#
#       Population Change (2010-2019)  Population Change %  Population-Sq Mile
# 0                              1096                  2.0                92.4  \
# 1                             40122                 18.0               110.1
# 2                             -2641                -10.7                27.3
# 3                              -476                 -2.1                35.8
# 4                               450                  0.8                88.9
# ...                             ...                  ...                 ...
# 3519                          -1231                 -2.9                 4.0
# 3520                           2168                  9.2                 5.6
# 3521                           -863                 -4.3                 9.7
# 3522                           -725                 -9.3                 3.5
# 3523                           -271                 -3.9                 2.9
#
#      property_count state_abbrev  county_qualified_name
# 0             32525           AL     Autauga County, AL
# 1            146556           AL     Baldwin County, AL
# 2             24839           AL     Barbour County, AL
# 3             24839           AL        Bibb County, AL
# 4             43230           AL      Blount County, AL
# ...             ...          ...                    ...
# 3519          26566           WY  Sweetwater County, WY
# 3520          15006           WY       Teton County, WY
# 3521          15160           WY       Uinta County, WY
# 3522           5131           WY    Washakie County, WY
# 3523           5664           WY      Weston County, WY
#
# [3524 rows x 34 columns]

# %%
merged_df = redfin_df.merge(prcyd_df, how='inner', on='county_qualified_name')
merged_df
# Out:
#                  county_qualified_name  homes_sold_redfin
# 0                   Denali Borough, AK                1.0  \
# 1     Fairbanks North Star Borough, AK               76.0
# 2          Kenai Peninsula Borough, AK               43.4
# 3            Kodiak Island Borough, AK                2.4
# 4        Matanuska-Susitna Borough, AK              122.6
# ...                                ...                ...
# 3195              Hampshire County, WV               19.0
# 3196                  Hardy County, WV                9.6
# 3197              Jefferson County, WV               75.4
# 3198                Mineral County, WV               16.6
# 3199                 Morgan County, WV               23.8
#
#       new_listings_redfin  inventory_redfin  median_dom_redfin
# 0                     1.0               3.0               67.5  \
# 1                   107.6             209.4               67.0
# 2                    77.6             157.0               29.4
# 3                     4.8               6.6               64.0
# 4                   180.2             285.2               32.2
# ...                   ...               ...                ...
# 3195                 26.0              62.6               38.8
# 3196                 12.4              32.2               63.4
# 3197                 88.6             192.8               55.2
# 3198                 19.8              49.4               58.6
# 3199                 25.0              72.2               70.8
#
#       months_of_supply_redfin state_code                   county_name
# 0                        3.00         AK                Denali Borough  \
# 1                        3.10         AK  Fairbanks North Star Borough
# 2                        4.06         AK       Kenai Peninsula Borough
# 3                        4.46         AK         Kodiak Island Borough
# 4                        2.46         AK     Matanuska-Susitna Borough
# ...                       ...        ...                           ...
# 3195                     3.48         WV              Hampshire County
# 3196                     3.38         WV                  Hardy County
# 3197                     2.64         WV              Jefferson County
# 3198                     3.12         WV                Mineral County
# 3199                     3.10         WV                 Morgan County
#
#       months_averaged_redfin                        County          State
# 0                          3                Denali Borough         Alaska  \
# 1                          3  Fairbanks North Star Borough         Alaska
# 2                          3       Kenai Peninsula Borough         Alaska
# 3                          3         Kodiak Island Borough         Alaska
# 4                          3     Matanuska-Susitna Borough         Alaska
# ...                      ...                           ...            ...
# 3195                       3              Hampshire County  West Virginia
# 3196                       3                  Hardy County  West Virginia
# 3197                       3              Jefferson County  West Virginia
# 3198                       3                Mineral County  West Virginia
# 3199                       3                 Morgan County  West Virginia
#
#       Total Comps  For Sale Comps (All)  Sold Comps (All)  Sold Comps (6m)
# 0              98                    98                 0                0  \
# 1            2456                  2441                15                1
# 2            3039                  2708               331              110
# 3             183                   180                 3                0
# 4            3260                  3093               167               62
# ...           ...                   ...               ...              ...
# 3195         3920                  2852              1068              181
# 3196         1539                  1180               359               78
# 3197         1157                   964               193               77
# 3198         1305                  1145               160               31
# 3199         2023                  1582               441              228
#
#       Sold Comps (3m)  Listed Comps (12m)  Listed Comps (6m)
# 0                   0                  39                 20  \
# 1                   0                 428                179
# 2                  36                1134                491
# 3                   0                  81                 55
# 4                  25                1114                722
# ...               ...                 ...                ...
# 3195               78                 344                179
# 3196               37                 128                 61
# 3197               38                 182                106
# 3198               17                  99                 60
# 3199              172                 127                 79
#
#       Listed Comps (3m)  Sold-For Sale Ratio  Sold-Listed Ratio (12m)
# 0                     0                 0.00                     0.00  \
# 1                   124                 0.01                     0.04
# 2                   354                 0.12                     0.29
# 3                    30                 0.02                     0.04
# 4                   477                 0.05                     0.15
# ...                 ...                  ...                      ...
# 3195                109                 0.37                     3.10
# 3196                 41                 0.30                     2.80
# 3197                 75                 0.20                     1.06
# 3198                 27                 0.14                     1.62
# 3199                 47                 0.28                     3.47
#
#       Sold-Listed Ratio (6m)  Sold-Listed Ratio (3m)  Parcels on Market Ratio
# 0                       0.00                    0.00                    0.000  \
# 1                       0.01                    0.00                    0.229
# 2                       0.22                    0.10                    0.094
# 3                       0.00                    0.00                    0.068
# 4                       0.09                    0.05                   17.574
# ...                      ...                     ...                      ...
# 3195                    1.01                    0.72                    0.355
# 3196                    1.28                    0.90                    0.171
# 3197                    0.73                    0.51                    0.149
# 3198                    0.52                    0.63                    0.185
# 3199                    2.89                    3.66                    0.321
#
#       Total DataTree Parcels  Total Out of State Owner Parcels
# 0                          0                                 0  \
# 1                      10651                              1315
# 2                      28846                              5901
# 3                       2633                               262
# 4                        176                                 8
# ...                      ...                               ...
# 3195                    8039                              3575
# 3196                    6914                              2263
# 3197                    6462                              2122
# 3198                    6177                               978
# 3199                    4924                              2089
#
#       Total Out of County Owner Parcels  Out of State to Total Ratio
# 0                                     0                        0.000  \
# 1                                  1972                        0.123
# 2                                 15085                        0.205
# 3                                  1200                        0.100
# 4                                    44                        0.045
# ...                                 ...                          ...
# 3195                               4466                        0.445
# 3196                               3210                        0.327
# 3197                               2432                        0.328
# 3198                               1410                        0.158
# 3199                               2573                        0.424
#
#       Out of County to Total Ratio  Coefficient of Variation
# 0                            0.000                      0.16  \
# 1                            0.185                      0.55
# 2                            0.523                      0.63
# 3                            0.456                      0.10
# 4                            0.250                      1.02
# ...                            ...                       ...
# 3195                         0.556                      1.10
# 3196                         0.464                      0.28
# 3197                         0.376                      0.35
# 3198                         0.228                      0.35
# 3199                         0.523                      0.34
#
#       Coefficient of Variation (6m)  Coefficient of Variation (3m)
# 0                              0.16                           0.16  \
# 1                              0.55                           0.55
# 2                              0.62                           0.63
# 3                              0.10                           0.10
# 4                              1.01                           1.01
# ...                             ...                            ...
# 3195                           1.06                           1.03
# 3196                           0.27                           0.27
# 3197                           0.35                           0.36
# 3198                           0.34                           0.34
# 3199                           0.33                           0.33
#
#       Days on Market  MoM Price Change %  Economic Rank  Economic Score
# 0              274.8              -10.44         1305.0            0.08  \
# 1              286.0                1.26         1323.0            0.07
# 2              279.5               -2.37         1328.0            0.07
# 3              235.7              -15.28         2346.0           -0.86
# 4              213.6                2.95         1194.0            0.18
# ...              ...                 ...            ...             ...
# 3195           180.5                0.78          788.0            0.62
# 3196           296.4               -1.15          982.0            0.39
# 3197           350.3                0.99         2303.0           -0.81
# 3198           995.0                0.28          801.0            0.61
# 3199           207.1                1.57         1050.0            0.32
#
#       Population  Population Change (2010-2019)  Population Change %
# 0           2097                            262                 12.5  \
# 1          96849                          -1415                 -1.5
# 2          58708                           3154                  5.4
# 3          12998                           -648                 -5.0
# 4         108317                          18585                 17.2
# ...          ...                            ...                  ...
# 3195       23175                           -777                 -3.4
# 3196       13776                           -268                 -1.9
# 3197       57146                           3537                  6.2
# 3198       26868                          -1337                 -5.0
# 3199       17884                            393                  2.2
#
#       Population-Sq Mile property_count state_abbrev
# 0                    0.2            NaN           AK
# 1                   13.0            NaN           AK
# 2                    2.4            NaN           AK
# 3                    1.1            NaN           AK
# 4                    4.3            NaN           AK
# ...                  ...            ...          ...
# 3195                36.0          21515           WV
# 3196                23.6          14724           WV
# 3197               270.1          33759           WV
# 3198                81.6          19151           WV
# 3199                77.9          15067           WV
#
# [3200 rows x 42 columns]

# %%
combined_df = merged_df.dropna(subset=['property_count', 'inventory_redfin']).copy()
combined_df
# Out:
#      county_qualified_name  homes_sold_redfin  new_listings_redfin
# 5       Autauga County, AL               48.0                 64.4  \
# 6       Baldwin County, AL              530.6                714.2
# 7       Barbour County, AL               11.4                 16.0
# 8          Bibb County, AL                7.2                  8.2
# 9        Blount County, AL               38.8                 42.4
# ...                    ...                ...                  ...
# 3195  Hampshire County, WV               19.0                 26.0
# 3196      Hardy County, WV                9.6                 12.4
# 3197  Jefferson County, WV               75.4                 88.6
# 3198    Mineral County, WV               16.6                 19.8
# 3199     Morgan County, WV               23.8                 25.0
#
#       inventory_redfin  median_dom_redfin  months_of_supply_redfin state_code
# 5                125.2               45.8                     2.68         AL  \
# 6               1735.2               50.0                     3.34         AL
# 7                 59.0               70.4                     5.66         AL
# 8                 22.0               59.0                     3.66         AL
# 9                104.8               51.4                     2.86         AL
# ...                ...                ...                      ...        ...
# 3195              62.6               38.8                     3.48         WV
# 3196              32.2               63.4                     3.38         WV
# 3197             192.8               55.2                     2.64         WV
# 3198              49.4               58.6                     3.12         WV
# 3199              72.2               70.8                     3.10         WV
#
#            county_name  months_averaged_redfin            County
# 5       Autauga County                       3    Autauga County  \
# 6       Baldwin County                       3    Baldwin County
# 7       Barbour County                       3    Barbour County
# 8          Bibb County                       3       Bibb County
# 9        Blount County                       3     Blount County
# ...                ...                     ...               ...
# 3195  Hampshire County                       3  Hampshire County
# 3196      Hardy County                       3      Hardy County
# 3197  Jefferson County                       3  Jefferson County
# 3198    Mineral County                       3    Mineral County
# 3199     Morgan County                       3     Morgan County
#
#               State  Total Comps  For Sale Comps (All)  Sold Comps (All)
# 5           Alabama          875                   637               238  \
# 6           Alabama         8097                  5402              2695
# 7           Alabama          677                   612                65
# 8           Alabama          267                   177                90
# 9           Alabama         1128                   809               319
# ...             ...          ...                   ...               ...
# 3195  West Virginia         3920                  2852              1068
# 3196  West Virginia         1539                  1180               359
# 3197  West Virginia         1157                   964               193
# 3198  West Virginia         1305                  1145               160
# 3199  West Virginia         2023                  1582               441
#
#       Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)  Listed Comps (6m)
# 5                  70               36                 212                185  \
# 6                 930              378                2678               1907
# 7                   8                5                 224                154
# 8                  19                7                  69                 47
# 9                  79               42                 291                199
# ...               ...              ...                 ...                ...
# 3195              181               78                 344                179
# 3196               78               37                 128                 61
# 3197               77               38                 182                106
# 3198               31               17                  99                 60
# 3199              228              172                 127                 79
#
#       Listed Comps (3m)  Sold-For Sale Ratio  Sold-Listed Ratio (12m)
# 5                    50                 0.37                     1.12  \
# 6                  1205                 0.50                     1.01
# 7                    72                 0.11                     0.29
# 8                    19                 0.51                     1.30
# 9                   139                 0.39                     1.10
# ...                 ...                  ...                      ...
# 3195                109                 0.37                     3.10
# 3196                 41                 0.30                     2.80
# 3197                 75                 0.20                     1.06
# 3198                 27                 0.14                     1.62
# 3199                 47                 0.28                     3.47
#
#       Sold-Listed Ratio (6m)  Sold-Listed Ratio (3m)  Parcels on Market Ratio
# 5                       0.38                    0.72                    0.080  \
# 6                       0.49                    0.31                    0.139
# 7                       0.05                    0.07                    0.048
# 8                       0.40                    0.37                    0.022
# 9                       0.40                    0.30                    0.039
# ...                      ...                     ...                      ...
# 3195                    1.01                    0.72                    0.355
# 3196                    1.28                    0.90                    0.171
# 3197                    0.73                    0.51                    0.149
# 3198                    0.52                    0.63                    0.185
# 3199                    2.89                    3.66                    0.321
#
#       Total DataTree Parcels  Total Out of State Owner Parcels
# 5                       8002                               991  \
# 6                      38984                              6143
# 7                      12726                              2459
# 8                       8058                               873
# 9                      20841                              1148
# ...                      ...                               ...
# 3195                    8039                              3575
# 3196                    6914                              2263
# 3197                    6462                              2122
# 3198                    6177                               978
# 3199                    4924                              2089
#
#       Total Out of County Owner Parcels  Out of State to Total Ratio
# 5                                  3121                        0.124  \
# 6                                 12890                        0.158
# 7                                  5429                        0.193
# 8                                  3363                        0.108
# 9                                  6146                        0.055
# ...                                 ...                          ...
# 3195                               4466                        0.445
# 3196                               3210                        0.327
# 3197                               2432                        0.328
# 3198                               1410                        0.158
# 3199                               2573                        0.424
#
#       Out of County to Total Ratio  Coefficient of Variation
# 5                            0.390                      0.88  \
# 6                            0.331                      1.19
# 7                            0.427                      0.60
# 8                            0.417                      0.40
# 9                            0.295                      0.77
# ...                            ...                       ...
# 3195                         0.556                      1.10
# 3196                         0.464                      0.28
# 3197                         0.376                      0.35
# 3198                         0.228                      0.35
# 3199                         0.523                      0.34
#
#       Coefficient of Variation (6m)  Coefficient of Variation (3m)
# 5                              0.68                           0.67  \
# 6                              1.17                           1.16
# 7                              0.59                           0.59
# 8                              0.36                           0.36
# 9                              0.70                           0.67
# ...                             ...                            ...
# 3195                           1.06                           1.03
# 3196                           0.27                           0.27
# 3197                           0.35                           0.36
# 3198                           0.34                           0.34
# 3199                           0.33                           0.33
#
#       Days on Market  MoM Price Change %  Economic Rank  Economic Score
# 5              479.8               -0.38          726.0            0.70  \
# 6              174.8                3.15          398.0            1.42
# 7              239.9                3.68         1647.0           -0.19
# 8              204.4               -0.18         1722.0           -0.24
# 9              258.0                0.42         1149.0            0.23
# ...              ...                 ...            ...             ...
# 3195           180.5                0.78          788.0            0.62
# 3196           296.4               -1.15          982.0            0.39
# 3197           350.3                0.99         2303.0           -0.81
# 3198           995.0                0.28          801.0            0.61
# 3199           207.1                1.57         1050.0            0.32
#
#       Population  Population Change (2010-2019)  Population Change %
# 5          55869                           1096                  2.0  \
# 6         223234                          40122                 18.0
# 7          24686                          -2641                -10.7
# 8          22394                           -476                 -2.1
# 9          57826                            450                  0.8
# ...          ...                            ...                  ...
# 3195       23175                           -777                 -3.4
# 3196       13776                           -268                 -1.9
# 3197       57146                           3537                  6.2
# 3198       26868                          -1337                 -5.0
# 3199       17884                            393                  2.2
#
#       Population-Sq Mile property_count state_abbrev
# 5                   92.4          32525           AL
# 6                  110.1         146556           AL
# 7                   27.3          24839           AL
# 8                   35.8          24839           AL
# 9                   88.9          43230           AL
# ...                  ...            ...          ...
# 3195                36.0          21515           WV
# 3196                23.6          14724           WV
# 3197               270.1          33759           WV
# 3198                81.6          19151           WV
# 3199                77.9          15067           WV
#
# [2838 rows x 42 columns]

# %%
# combined_df['county_unique'] = combined_df['county_qualified_name'] + ' - ' + combined_df['months_averaged_redfin'].astype(str)
combined_df['county_unique'] = combined_df['county_qualified_name']
cols = ['county_unique'] + [col for col in combined_df.columns if col != 'county_unique']

combined_df = combined_df[cols]
combined_df
# Out:
#              county_unique county_qualified_name  homes_sold_redfin
# 5       Autauga County, AL    Autauga County, AL               48.0  \
# 6       Baldwin County, AL    Baldwin County, AL              530.6
# 7       Barbour County, AL    Barbour County, AL               11.4
# 8          Bibb County, AL       Bibb County, AL                7.2
# 9        Blount County, AL     Blount County, AL               38.8
# ...                    ...                   ...                ...
# 3195  Hampshire County, WV  Hampshire County, WV               19.0
# 3196      Hardy County, WV      Hardy County, WV                9.6
# 3197  Jefferson County, WV  Jefferson County, WV               75.4
# 3198    Mineral County, WV    Mineral County, WV               16.6
# 3199     Morgan County, WV     Morgan County, WV               23.8
#
#       new_listings_redfin  inventory_redfin  median_dom_redfin
# 5                    64.4             125.2               45.8  \
# 6                   714.2            1735.2               50.0
# 7                    16.0              59.0               70.4
# 8                     8.2              22.0               59.0
# 9                    42.4             104.8               51.4
# ...                   ...               ...                ...
# 3195                 26.0              62.6               38.8
# 3196                 12.4              32.2               63.4
# 3197                 88.6             192.8               55.2
# 3198                 19.8              49.4               58.6
# 3199                 25.0              72.2               70.8
#
#       months_of_supply_redfin state_code       county_name
# 5                        2.68         AL    Autauga County  \
# 6                        3.34         AL    Baldwin County
# 7                        5.66         AL    Barbour County
# 8                        3.66         AL       Bibb County
# 9                        2.86         AL     Blount County
# ...                       ...        ...               ...
# 3195                     3.48         WV  Hampshire County
# 3196                     3.38         WV      Hardy County
# 3197                     2.64         WV  Jefferson County
# 3198                     3.12         WV    Mineral County
# 3199                     3.10         WV     Morgan County
#
#       months_averaged_redfin            County          State  Total Comps
# 5                          3    Autauga County        Alabama          875  \
# 6                          3    Baldwin County        Alabama         8097
# 7                          3    Barbour County        Alabama          677
# 8                          3       Bibb County        Alabama          267
# 9                          3     Blount County        Alabama         1128
# ...                      ...               ...            ...          ...
# 3195                       3  Hampshire County  West Virginia         3920
# 3196                       3      Hardy County  West Virginia         1539
# 3197                       3  Jefferson County  West Virginia         1157
# 3198                       3    Mineral County  West Virginia         1305
# 3199                       3     Morgan County  West Virginia         2023
#
#       For Sale Comps (All)  Sold Comps (All)  Sold Comps (6m)
# 5                      637               238               70  \
# 6                     5402              2695              930
# 7                      612                65                8
# 8                      177                90               19
# 9                      809               319               79
# ...                    ...               ...              ...
# 3195                  2852              1068              181
# 3196                  1180               359               78
# 3197                   964               193               77
# 3198                  1145               160               31
# 3199                  1582               441              228
#
#       Sold Comps (3m)  Listed Comps (12m)  Listed Comps (6m)
# 5                  36                 212                185  \
# 6                 378                2678               1907
# 7                   5                 224                154
# 8                   7                  69                 47
# 9                  42                 291                199
# ...               ...                 ...                ...
# 3195               78                 344                179
# 3196               37                 128                 61
# 3197               38                 182                106
# 3198               17                  99                 60
# 3199              172                 127                 79
#
#       Listed Comps (3m)  Sold-For Sale Ratio  Sold-Listed Ratio (12m)
# 5                    50                 0.37                     1.12  \
# 6                  1205                 0.50                     1.01
# 7                    72                 0.11                     0.29
# 8                    19                 0.51                     1.30
# 9                   139                 0.39                     1.10
# ...                 ...                  ...                      ...
# 3195                109                 0.37                     3.10
# 3196                 41                 0.30                     2.80
# 3197                 75                 0.20                     1.06
# 3198                 27                 0.14                     1.62
# 3199                 47                 0.28                     3.47
#
#       Sold-Listed Ratio (6m)  Sold-Listed Ratio (3m)  Parcels on Market Ratio
# 5                       0.38                    0.72                    0.080  \
# 6                       0.49                    0.31                    0.139
# 7                       0.05                    0.07                    0.048
# 8                       0.40                    0.37                    0.022
# 9                       0.40                    0.30                    0.039
# ...                      ...                     ...                      ...
# 3195                    1.01                    0.72                    0.355
# 3196                    1.28                    0.90                    0.171
# 3197                    0.73                    0.51                    0.149
# 3198                    0.52                    0.63                    0.185
# 3199                    2.89                    3.66                    0.321
#
#       Total DataTree Parcels  Total Out of State Owner Parcels
# 5                       8002                               991  \
# 6                      38984                              6143
# 7                      12726                              2459
# 8                       8058                               873
# 9                      20841                              1148
# ...                      ...                               ...
# 3195                    8039                              3575
# 3196                    6914                              2263
# 3197                    6462                              2122
# 3198                    6177                               978
# 3199                    4924                              2089
#
#       Total Out of County Owner Parcels  Out of State to Total Ratio
# 5                                  3121                        0.124  \
# 6                                 12890                        0.158
# 7                                  5429                        0.193
# 8                                  3363                        0.108
# 9                                  6146                        0.055
# ...                                 ...                          ...
# 3195                               4466                        0.445
# 3196                               3210                        0.327
# 3197                               2432                        0.328
# 3198                               1410                        0.158
# 3199                               2573                        0.424
#
#       Out of County to Total Ratio  Coefficient of Variation
# 5                            0.390                      0.88  \
# 6                            0.331                      1.19
# 7                            0.427                      0.60
# 8                            0.417                      0.40
# 9                            0.295                      0.77
# ...                            ...                       ...
# 3195                         0.556                      1.10
# 3196                         0.464                      0.28
# 3197                         0.376                      0.35
# 3198                         0.228                      0.35
# 3199                         0.523                      0.34
#
#       Coefficient of Variation (6m)  Coefficient of Variation (3m)
# 5                              0.68                           0.67  \
# 6                              1.17                           1.16
# 7                              0.59                           0.59
# 8                              0.36                           0.36
# 9                              0.70                           0.67
# ...                             ...                            ...
# 3195                           1.06                           1.03
# 3196                           0.27                           0.27
# 3197                           0.35                           0.36
# 3198                           0.34                           0.34
# 3199                           0.33                           0.33
#
#       Days on Market  MoM Price Change %  Economic Rank  Economic Score
# 5              479.8               -0.38          726.0            0.70  \
# 6              174.8                3.15          398.0            1.42
# 7              239.9                3.68         1647.0           -0.19
# 8              204.4               -0.18         1722.0           -0.24
# 9              258.0                0.42         1149.0            0.23
# ...              ...                 ...            ...             ...
# 3195           180.5                0.78          788.0            0.62
# 3196           296.4               -1.15          982.0            0.39
# 3197           350.3                0.99         2303.0           -0.81
# 3198           995.0                0.28          801.0            0.61
# 3199           207.1                1.57         1050.0            0.32
#
#       Population  Population Change (2010-2019)  Population Change %
# 5          55869                           1096                  2.0  \
# 6         223234                          40122                 18.0
# 7          24686                          -2641                -10.7
# 8          22394                           -476                 -2.1
# 9          57826                            450                  0.8
# ...          ...                            ...                  ...
# 3195       23175                           -777                 -3.4
# 3196       13776                           -268                 -1.9
# 3197       57146                           3537                  6.2
# 3198       26868                          -1337                 -5.0
# 3199       17884                            393                  2.2
#
#       Population-Sq Mile property_count state_abbrev
# 5                   92.4          32525           AL
# 6                  110.1         146556           AL
# 7                   27.3          24839           AL
# 8                   35.8          24839           AL
# 9                   88.9          43230           AL
# ...                  ...            ...          ...
# 3195                36.0          21515           WV
# 3196                23.6          14724           WV
# 3197               270.1          33759           WV
# 3198                81.6          19151           WV
# 3199                77.9          15067           WV
#
# [2838 rows x 43 columns]

# %%
export_df = combined_df.drop(columns=['County', 'State', 'state_abbrev', 'county_qualified_name'])

# %%
today = datetime.date.today()
date_string = today.strftime("%Y-%m-%d")
# file_path_tsv = f"processed/combined_county_data_{date_string}.tsv"
file_path = f"processed/combined_county_data_{date_string}.xlsx"

# %%
export_df.to_excel(file_path, index=False)
