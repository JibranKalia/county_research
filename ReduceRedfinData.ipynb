# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
df_original = pd.read_csv('/Users/jibrank/Library/Mobile Documents/com~apple~CloudDocs/Land/Data/county_market_tracker.tsv', sep='\t')
df_original.shape
# Out:
# (863949, 58)

# %%
df = df_original.copy()

# %%
# Convert 'period_begin' to datetime if it's not already
df['period_begin'] = pd.to_datetime(df['period_begin'])
df = df[df['property_type'] == 'All Residential']

# Filter to include only rows where 'period_begin' is in 2022 or after
df_2022_and_after = df[df['period_begin'] >= '2022-01-01']
df_2022_and_after.shape
# Out:
# (39437, 58)

# %%
df = df_2022_and_after.loc[:, ['period_begin', 'region', 'state', 'state_code', 'property_type', 'homes_sold', 'new_listings', 'inventory', 'median_dom', 'months_of_supply', 'avg_sale_to_list', 'last_updated']]
df = df.sort_values(by='period_begin', ascending=False)
df = df.reset_index(drop=True)
df = df.rename(columns={'region':'county', 'period_begin': 'month'})
df['county_name'] = df['county'].apply(lambda x: x.split(',')[0] if ',' in x else x)
df
# Out:
#            month                county           state state_code
# 0     2023-03-01      Wayne County, IL        Illinois         IL  \
# 1     2023-03-01  Henderson County, NC  North Carolina         NC
# 2     2023-03-01   McDonald County, MO        Missouri         MO
# 3     2023-03-01   Cherokee County, AL         Alabama         AL
# 4     2023-03-01      Atoka County, OK        Oklahoma         OK
# ...          ...                   ...             ...        ...
# 39432 2022-01-01     Hardin County, TX           Texas         TX
# 39433 2022-01-01  Lunenburg County, VA        Virginia         VA
# 39434 2022-01-01     Phelps County, MO        Missouri         MO
# 39435 2022-01-01   Franklin Parish, LA       Louisiana         LA
# 39436 2022-01-01  Abbeville County, SC  South Carolina         SC
#
#          property_type  homes_sold  new_listings  inventory  median_dom
# 0      All Residential         3.0           1.0        4.0        20.0  \
# 1      All Residential       134.0         187.0      405.0        48.0
# 2      All Residential        10.0          15.0       31.0        31.0
# 3      All Residential        12.0          24.0       80.0        54.0
# 4      All Residential         4.0           8.0       35.0        35.0
# ...                ...         ...           ...        ...         ...
# 39432  All Residential        54.0          60.0      117.0        46.0
# 39433  All Residential         7.0           2.0       15.0        74.0
# 39434  All Residential        44.0          29.0       97.0        48.0
# 39435  All Residential         8.0           5.0       17.0       102.0
# 39436  All Residential         9.0          16.0       39.0       105.0
#
#        months_of_supply  avg_sale_to_list         last_updated
# 0                   1.3          0.931687  2023-04-09 14:55:08  \
# 1                   3.0          0.985260  2023-04-09 14:55:08
# 2                   3.1          0.955679  2023-04-09 14:55:08
# 3                   6.7          0.965520  2023-04-09 14:55:08
# 4                   8.8          0.960579  2023-04-09 14:55:08
# ...                 ...               ...                  ...
# 39432               2.2          0.956617  2023-04-09 14:55:08
# 39433               2.1          1.010519  2023-04-09 14:55:08
# 39434               2.2          0.969478  2023-04-09 14:55:08
# 39435               2.1          0.870611  2023-04-09 14:55:08
# 39436               4.3          0.890377  2023-04-09 14:55:08
#
#             county_name
# 0          Wayne County
# 1      Henderson County
# 2       McDonald County
# 3       Cherokee County
# 4          Atoka County
# ...                 ...
# 39432     Hardin County
# 39433  Lunenburg County
# 39434     Phelps County
# 39435   Franklin Parish
# 39436  Abbeville County
#
# [39437 rows x 13 columns]

# %%
# Drop the 'county' and 'state' columns
df = df.drop(columns=['county', 'state'])

# Rearrange the columns
df = df[['month', 'county_name', 'state_code', 'property_type', 'homes_sold', 'new_listings', 'inventory', 
         'median_dom', 'months_of_supply', 'avg_sale_to_list', 'last_updated']]

df = df.sort_values(by=['state_code', 'county_name', 'month'])
df
# Out:
#            month        county_name state_code    property_type  homes_sold
# 38199 2022-01-01  Anchorage Borough         AK  All Residential       299.0  \
# 36157 2022-02-01  Anchorage Borough         AK  All Residential       275.0
# 33222 2022-03-01  Anchorage Borough         AK  All Residential       331.0
# 31173 2022-04-01  Anchorage Borough         AK  All Residential       382.0
# 26929 2022-05-01  Anchorage Borough         AK  All Residential       451.0
# ...          ...                ...        ...              ...         ...
# 12725 2022-11-01      Morgan County         WV  All Residential        32.0
# 9030  2022-12-01      Morgan County         WV  All Residential        13.0
# 6360  2023-01-01      Morgan County         WV  All Residential        22.0
# 4054  2023-02-01      Morgan County         WV  All Residential        19.0
# 1737  2023-03-01      Morgan County         WV  All Residential        25.0
#
#        new_listings  inventory  median_dom  months_of_supply
# 38199         261.0      282.0        23.0               0.9  \
# 36157         376.0      260.0        26.0               0.9
# 33222         520.0      339.0        10.0               1.0
# 31173         588.0      412.0         7.0               1.1
# 26929         581.0      490.0         6.0               1.1
# ...             ...        ...         ...               ...
# 12725          21.0       85.0        51.0               2.7
# 9030           18.0       82.0        38.0               6.3
# 6360           19.0       70.0       129.0               3.2
# 4054           32.0       75.0        69.0               3.9
# 1737           24.0       73.0        45.0               2.9
#
#        avg_sale_to_list         last_updated
# 38199          0.997268  2023-04-09 14:55:08
# 36157          0.999285  2023-04-09 14:55:08
# 33222          1.007284  2023-04-09 14:55:08
# 31173          1.016928  2023-04-09 14:55:08
# 26929          1.021409  2023-04-09 14:55:08
# ...                 ...                  ...
# 12725          0.967970  2023-04-09 14:55:08
# 9030           0.975503  2023-04-09 14:55:08
# 6360           0.942904  2023-04-09 14:55:08
# 4054           0.945075  2023-04-09 14:55:08
# 1737           0.989359  2023-04-09 14:55:08
#
# [39437 rows x 11 columns]

# %%
today = datetime.date.today()
date_string = today.strftime("%Y-%m")
file_path = f"data/redfin_county_data_{date_string}.tsv"

# %%
df.to_csv(file_path, index=False, sep ='\t')
