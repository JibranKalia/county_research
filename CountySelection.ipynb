# %% [markdown]
# <a href="https://colab.research.google.com/github/JibranKalia/county_research/blob/main/CountySelection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_original = pd.read_csv('/content/drive/My Drive/Land/redfin_data_dec_2022_to_dec_2023.csv')

# %%
df = df_original.copy()

# %%
# Fill the missing values in the 'Region' column with the previous non-empty value

df['Region'] = df['Region'].fillna(method='ffill')
df.head(5)
# Out:
#                  Region Month of Period End Median Sale Price  \
# 0  Abbeville County, SC       December 2021             $159K
# 1  Abbeville County, SC        January 2022             $155K
# 2  Abbeville County, SC       February 2022             $240K
# 3  Abbeville County, SC          March 2022             $162K
# 4  Abbeville County, SC          April 2022             $160K
#
#   Median Sale Price MoM  Median Sale Price YoY  Homes Sold Homes Sold MoM   \
# 0                 -27.7%                   0.6%         11          120.0%
# 1                  -2.5%                 -27.9%          6          -45.5%
# 2                  54.8%                   8.1%          7           16.7%
# 3                 -32.7%                  29.2%         12           71.4%
# 4                  -0.9%                 -28.9%          5          -58.3%
#
#   Homes Sold YoY  New Listings New Listings MoM  New Listings YoY  Inventory  \
# ...
