# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
county_wise_df_orig = pd.read_excel('data/county_wise_2023-05.xlsx')
county_wise_df_orig
# Out:
#                  County    State property_count population_2015  square_miles
# 0        Autauga County  Alabama          32525           55246         604.0  \
# 1        Baldwin County  Alabama         146556          195540        2027.0
# 2        Barbour County  Alabama          24839           22512         905.0
# 3           Bibb County  Alabama          24839           27076         626.0
# 4         Blount County  Alabama          43230           57872         651.0
# ...                 ...      ...            ...             ...           ...
# 3167  Sweetwater County  Wyoming          26566           45237       10491.0
# 3168       Teton County  Wyoming          15006           22268        4216.0
# 3169       Uinta County  Wyoming          15160           21066        2088.0
# 3170    Washakie County  Wyoming           5131            8463        2243.0
# 3171      Weston County  Wyoming           5664            7158        2400.0
#
#      people/sqmiles
# ...

# %%
prcyd_df = pd.read_excel('data/prcyd_data_2023-07.xlsx')
prcyd_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3192  Sweetwater County  Wyoming          196                   143
# 3193       Teton County  Wyoming         1223                  1220
# 3194       Uinta County  Wyoming          192                   191
# 3195    Washakie County  Wyoming           94                    90
# 3196      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# ...

# %%
merged_df = prcyd_df.merge(county_wise_df_orig[['County', 'State', 'property_count']], how='left', on=['County', 'State'])

merged_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3519  Sweetwater County  Wyoming          196                   143
# 3520       Teton County  Wyoming         1223                  1220
# 3521       Uinta County  Wyoming          192                   191
# 3522    Washakie County  Wyoming           94                    90
# 3523      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# ...

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
# Ensure state names in your dataframe are title-cased to match the dictionary keys
merged_df['State'] = merged_df['State'].str.title()
merged_df['state_abbrev'] = merged_df['State'].map(us_state_to_abbrev)
merged_df['county_qualified_name'] = merged_df['County'] + ', ' + merged_df['state_abbrev']

merged_df
# Out:
#                  County    State  Total Comps  For Sale Comps (All)
# 0        Autauga County  Alabama          875                   637  \
# 1        Baldwin County  Alabama         8097                  5402
# 2        Barbour County  Alabama          677                   612
# 3           Bibb County  Alabama          267                   177
# 4         Blount County  Alabama         1128                   809
# ...                 ...      ...          ...                   ...
# 3519  Sweetwater County  Wyoming          196                   143
# 3520       Teton County  Wyoming         1223                  1220
# 3521       Uinta County  Wyoming          192                   191
# 3522    Washakie County  Wyoming           94                    90
# 3523      Weston County  Wyoming          280                   264
#
#       Sold Comps (All)  Sold Comps (6m)  Sold Comps (3m)  Listed Comps (12m)
# ...

# %%
today = datetime.date.today()
date_string = today.strftime("%Y-%m")
file_path = f"processed/prycd_county_data_{date_string}.xlsx"

# %%
merged_df.to_excel(file_path, index=False)
