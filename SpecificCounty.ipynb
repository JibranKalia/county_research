# %%
import pandas as pd
import datetime

pd.set_option('display.max_columns', 85)

# %%
df_orig = pd.read_csv('processed/combined_county_data_2023-06-08.tsv', sep='\t')

# %%
df_orig.loc[(df_orig['county_name'] == 'Caldwell County') & (df_orig['state_code'] == 'NC')]
# Out:
#                  county_unique  homes_sold_redfin  new_listings_redfin
# 8475   Caldwell County, NC - 1              68.00                75.50  \
# 8476   Caldwell County, NC - 3              55.50                68.00
# 8477   Caldwell County, NC - 6              60.29                64.29
# 8478  Caldwell County, NC - 12              69.46                76.00
# 8479  Caldwell County, NC - 18              67.88                75.31
#
#       inventory_redfin  median_dom_redfin  months_of_supply_redfin state_code
# 8475            155.00              46.00                     2.30         NC  \
# 8476            159.25              51.00                     3.05         NC
# 8477            161.00              48.00                     2.81         NC
# 8478            162.85              43.62                     2.48         NC
# 8479            154.56              44.12                     2.41         NC
#
#           county_name  months_averaged_redfin  Total Comps
# ...

# %%
df_orig.loc[(df_orig['county_name'] == 'Scioto County') & (df_orig['state_code'] == 'OH')]
# Out:
# Empty DataFrame
# Columns: [county_unique, homes_sold_redfin, new_listings_redfin, inventory_redfin, median_dom_redfin, months_of_supply_redfin, state_code, county_name, months_averaged_redfin, Total Comps, For Sale Comps (All), Sold Comps (All), Sold Comps (6m), Sold Comps (3m), Listed Comps (12m), Listed Comps (6m), Listed Comps (3m), Sold-For Sale Ratio, Sold-Listed Ratio (12m), Sold-Listed Ratio (6m), Sold-Listed Ratio (3m), Parcels on Market Ratio, Total DataTree Parcels, Total Out of State Owner Parcels, Total Out of County Owner Parcels, Out of State to Total Ratio, Out of County to Total Ratio, Coefficient of Variation, Coefficient of Variation (6m), Coefficient of Variation (3m), Days on Market, MoM Price Change %, Economic Rank, Economic Score, Population, Population Change (2010-2019), Population Change %, Population-Sq Mile, property_count]
# Index: []
